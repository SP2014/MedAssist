# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("http://www.diseasesdatabase.com/item_choice.asp?strUserInput=cancer&bytSearchType=0")

# %%
page
# Out:
# <Response [410]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#print(soup.prettify())
list(soup.children)
# Out:
# []

# %%
body = list(soup.children)[3]

# %%
body
#list(html.children)
# Out:
# <body class="ezCSS">
# <div class="space30 ezCSS"></div>
# <div class="content ezCSS">
# <div class="container site ezCSS" style="width:1007px!important;padding-left:21px!important;padding-right:21px!important;border-left-width:1px!important;border-right-width:1px!important;border-top-width:1px!important;border-bottom-width:1px!important;">
# <div class="row ezCSS" style="margin-left:-22px!important;">
# <div class="span12 ezCSS" style="width:1007px!important;margin-left:21px!important;">
# <div class="row ezCSS" style="margin-left:-22px!important;">
# <div class="span8 logo ezoic-template-logo ezCSS" style="width:664px!important;margin-left:21px!important;">
# <div class="html5header ezCSS" id="ezoic-logo">
# <div class="html5hgroup ezCSS" id="logoText">
# <h1 class="ezomat-logo-text ezCSS" id="siteName">
# <a class="ezCSS" href="http://hindimeaning.com">HindiMeaning.com</a>
# </h1>
# </div>
# </div>
# </div>
# ...

# %%
#body

# %%
soup.find_all('p')
# Out:
# [<p cwidth="660" eza="cwidth:660px;;cheight:117px;;wcalc_source:child;wcalc:100px;wocalc:100px;hcalc:144px;rend_px_area:77220;" style="background-color:transparent;nodepath:/html/body/div[1]/div/div/main/article/div/p[1];pagepos:116;cwidth:660px;cheight:117px;wcalc_source:child;wcalc:100px;wocalc:100px;hcalc:144;rend_px_area:77220;rcnt:1;ez_min_text_wdth:53;req_px_area:22032;obj_px_area:8100;req_px_height:27;req_margin_and_padding:24;req_ns_height:;vertical_margin:24;parent-line-height:27px;margin-for-scale:0px 0px 24px 0px;margin:0px 0px 24px 0px;padding-for-scale:0px 0px 0px 0px;padding:0px 0px 0px 0px;">1. Hair – बाल – [Baal]<br/> <img class="toggleimage" cwidth="100" data-orig-width="100" eza="cwidth:100px;;cheight:81px;;wcalc_source:defined;wcalc:100px;wocalc:100px;hcalc:81px;rend_px_area:8100;" src="http://www.hindimeaning.com/wp-content/uploads/2013/08/Hair.jpg?x47669" style="max-width:100%;background-color:transparent;width:100px;height:auto;nodepath:/html/body/div[1]/div/div
# ...
